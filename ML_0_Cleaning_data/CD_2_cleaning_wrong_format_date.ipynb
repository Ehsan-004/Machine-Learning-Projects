# %%
import pandas as pd

# %% [markdown]
# If there are wrong formatted dates in your dataset you can either remove the row or you can use this method: `to_datetime()`

# %%
df = {
    "date": [
        '2020/12/01',
        None,
        '2020/02/20',
        '2020/12/05',
        '20201226'],
    "pulse": [
        100,
        140,
        120,
        110,
        100]
}

df = pd.DataFrame(df)

df['date'] = pd.to_datetime(df['date'])
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 18
#       1 df = {
#       2     "date": [
#       3         '2020/12/01',
#    (...)
#      13         100]
#      14 }
#      16 df = pd.DataFrame(df)
# ---> 18 df['date'] = pd.to_datetime(df['date'])
#      19 print(df)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...
